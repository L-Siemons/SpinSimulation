# %%
import spinSimulations.spin as ss
from spinSimulations.solver_H import prop_h, com_h, traj_prop_h

import numpy as np
import itertools

# %%
nuclei_list = 2 * ["1H"] + ["13C"]
n_spins = 3

# %%
s = ss.System(n_spins, is_sparse=False, nuclei_list=nuclei_list)

rho = s.singlet(0, 1)
pol_level = s.pol_level(2, "x")

dense_res = rho * pol_level

# %%
s = ss.System(n_spins, is_sparse=True, nuclei_list=nuclei_list)

# %%
rho = s.singlet(0, 1)

pol_level = s.pol_level(2, "x")

# %%
np.allclose(
    rho.multiply(pol_level).toarray(),
    dense_res
)
# Out:
# True

# %%
dense_res.sum()
# Out:
# 0j

# %%
rho
# Out:
# <8x8 sparse matrix of type '<class 'numpy.complex128'>'
# 	with 12 stored elements in Compressed Sparse Column format>
